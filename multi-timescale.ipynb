# %%
import matplotlib.pyplot as plt

import mhm

# %%
mhm.model.init(cwd="example_domain")

mhm.model.run()

runoff = mhm.get_runoff()

mhm.model.finalize()
# Out:
# ----------------------------------------------------------------------
#               mHM-UFZ
#
#     MULTISCALE HYDROLOGIC MODEL
#            Version: 5.13.1
#            Date:    Aug 2023
#
# Originally by L. Samaniego & R. Kumar
# ----------------------------------------------------------------------
#
# OpenMP used.
# Run with OpenMP with         12 threads.
#
# MPI not used.
#
# Start at 25.03.2024 16:28:58.
# Working directory: /Users/kangwang/Documents/GitHub/demos/example_domain
# Using namelists:
#      mhm.nml
#      mhm_parameter.nml
#      mhm_outputs.nml
#
#
# ***SELECTION: Neutron count routine is deativated!
#
# domain 1:
# resolution Hydrology (domain 1)     = 24000.
# resolution Routing (domain 1)       = 24000.
#
# Resolution of routing and hydrological modeling are equal!
#
# Following output will be written:
#   NetCDF deflate level: 6
#   NetCDF output precision: double
#     NetCDF output time reference point: start of time interval
#   STATES:
# ...

# %%
plt.plot(runoff[:, 0])
plt.show()
